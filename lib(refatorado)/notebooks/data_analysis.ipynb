# %% [markdown]
# ## Notebook Data Analysis para o RCE Framework Laucher usando Função objetivo - IEEE 14
# ---

# %% [markdown]
# ## 1) RCE Datasset

# %%
import pandas as pd


df_mutacao_100_gen = pd.read_excel("/home/pedrov12/Documentos/GitHub/Repopulation-With-Elite-Set/resultados - Artigo PIBIC/resultados - Agosto/resultados_consolidados_variando_mutaca_4x.xlsx")

df_resultados_4x_mutacao = pd.read_excel("/home/pedrov12/Documentos/GitHub/Repopulation-With-Elite-Set/resultados - Artigo PIBIC/resultados - Agosto/resultados_consolidados_variando_mutaca_4x.xlsx")


df_resultados_IEEE14_IEEE30_setembro = pd.read_csv("/home/pedrov12/Documentos/GitHub/Repopulation-With-Elite-Set/resultados - Artigo PIBIC/2025-09-01_resultados.csv")

df_resultados_Agosto_Laucher_Streamlit = pd.read_excel("/home/pedrov12/Documentos/GitHub/Repopulation-With-Elite-Set/resultados - Artigo PIBIC/resultados - Agosto/resultados.xlsx")


df_resultados_Agosto_Laucher_Streamlit = df_resultados_IEEE14_IEEE30_setembro

# %% [markdown]
# #### Este DF foi gerado pelo Launcher em output/resultados_consolidados.xlsx

# %%
df_resultados_Agosto_Laucher_Streamlit.head(3)
# Out:
#    Unnamed: 0                pasta_run configuracao  execucao  config_num  \
# 0           0  run_2025-08-29_01-11-02     config_1         1           1
# 1           1  run_2025-08-29_01-11-02     config_1         2           1
# 2           2  run_2025-08-29_01-11-02     config_1         3           1
#
#    param_CROSSOVER  param_DELTA_MIN  param_IND_SIZE  param_MUTACAO  \
# 0              0.9                2              10            0.9
# 1              0.9                2              10            0.9
# 2              0.9                2              10            0.9
#
#    param_NUM_GENERATIONS  ...  best_var_3  best_var_4  best_var_5  best_var_6  \
# 0                     20  ...          11          11          17         1.0
# 1                     20  ...          18          29          16        24.0
# 2                     20  ...          13          14          10         9.0
#
#    best_var_7  best_var_8  best_var_9  best_fitness  best_gen_idx  \
# 0        15.0        25.0        11.0     69.941159            18
# 1        29.0         9.0        20.0     70.440283            17
# 2         4.0        14.0         9.0     69.888380            17
#
#    fitness_function
# 0  function_IEEE_30
# 1  function_IEEE_30
# 2  function_IEEE_30
#
# [3 rows x 27 columns]

# %%
best_variables_df = df_resultados_Agosto_Laucher_Streamlit[["best_fitness","best_var_1", "best_var_2", "best_var_3", "best_var_4", "best_var_5", "best_var_6", "best_var_7", "best_var_8", "best_var_9", "configuracao", "execucao","fitness_function"]]

for i in range(best_variables_df.index.start + 1,best_variables_df.index.stop):
    pass

print("Tabela de Resultados por configuração")
display(best_variables_df)

print("Análise estátisticas como melhor fitness para problemas de minimização")
display(best_variables_df.describe())

print("Média por cada configuração e função objetivo")
best_variables_df.groupby(["configuracao", "fitness_function"]).mean()
# Out:
# Tabela de Resultados por configuração
#      best_fitness  best_var_1  best_var_2  best_var_3  best_var_4  best_var_5  \
# 0       69.941159           9          25          11          11          17
# 1       70.440283           2          24          18          29          16
# 2       69.888380           3           9          13          14          10
# 3       80.099917           1          14           1          19          12
# 4       79.733306          29          24          17          29          19
# ..            ...         ...         ...         ...         ...         ...
# 382     41.613011          10          17          10          10          18
# 383     50.635405          31           8          21          31          17
# 384     40.490471           0          31           0           0           6
# 385     52.512700          15           9          26          26          22
# 386     40.490471          31           1          31          31          17
#
#      best_var_6  best_var_7  best_var_8  best_var_9 configuracao  execucao  \
# 0           1.0        15.0        25.0        11.0     config_1         1
# 1          24.0        29.0         9.0        20.0     config_1         2
# 2           9.0         4.0        14.0         9.0     config_1         3
# 3          14.0        28.0        28.0        12.0     config_1         4
# 4          23.0        29.0        11.0        25.0     config_1         5
# ..          ...         ...         ...         ...          ...       ...
# 382         NaN         NaN         NaN         NaN     config_1         5
# 383         NaN         NaN         NaN         NaN     config_1         6
# 384         NaN         NaN         NaN         NaN     config_1         7
# 385         NaN         NaN         NaN         NaN     config_2         1
# 386         NaN         NaN         NaN         NaN     config_2         2
#
#      fitness_function
# 0    function_IEEE_30
# 1    function_IEEE_30
# 2    function_IEEE_30
# 3    function_IEEE_30
# 4    function_IEEE_30
# ..                ...
# 382  function_IEEE_14
# 383  function_IEEE_14
# 384  function_IEEE_14
# 385  function_IEEE_14
# 386  function_IEEE_14
#
# [387 rows x 13 columns]
# Análise estátisticas como melhor fitness para problemas de minimização
#        best_fitness  best_var_1  best_var_2  best_var_3  best_var_4  \
# count    387.000000  387.000000  387.000000  387.000000  387.000000
# mean      65.141737   14.899225   14.550388   14.878553   16.390181
# std       15.825596    9.568551   10.225915    8.942142   10.710762
# min       40.490471    0.000000    0.000000    0.000000    0.000000
# 25%       51.902473    6.000000    5.000000    7.000000    6.000000
# 50%       62.761874   14.000000   13.000000   14.000000   17.000000
# 75%       79.865992   23.500000   25.000000   22.000000   27.000000
# max      101.200339   31.000000   31.000000   31.000000   31.000000
#
#        best_var_5  best_var_6  best_var_7  best_var_8  best_var_9    execucao
# count  387.000000  192.000000  192.000000  192.000000  192.000000  387.000000
# mean    14.855297   14.583333   14.817708   14.406250   15.614583    4.180879
# std      8.248394   10.196156    9.609283   11.746964    8.563125    2.204176
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      8.000000    3.750000    7.000000    3.000000    8.000000    2.000000
# 50%     16.000000   14.000000   13.500000   10.000000   15.000000    4.000000
# 75%     21.000000   24.000000   25.000000   27.000000   22.000000    6.000000
# max     31.000000   31.000000   31.000000   31.000000   31.000000    9.000000
# Média por cada configuração e função objetivo
#                                best_fitness  best_var_1  best_var_2  \
# configuracao fitness_function
# config_1     function_IEEE_14     48.435175   13.979592   16.571429
#              function_IEEE_30     77.342243   13.857143   13.305195
# config_2     function_IEEE_14     48.867929   14.882353   13.588235
#              function_IEEE_30     75.758194   21.142857   16.785714
# config_3     function_IEEE_14     54.675838   15.408163   14.387755
#              function_IEEE_30     89.421577   13.714286   17.928571
# config_4     function_IEEE_14     56.095653   17.304348   15.434783
#              function_IEEE_30     86.152582   14.900000   17.600000
#
#                                best_var_3  best_var_4  best_var_5  best_var_6  \
# configuracao fitness_function
# config_1     function_IEEE_14   14.163265   18.857143   14.122449         NaN
#              function_IEEE_30   14.409091   14.870130   14.740260   13.876623
# config_2     function_IEEE_14   14.764706   15.078431   14.450980         NaN
#              function_IEEE_30   19.285714   18.000000   19.142857   15.142857
# config_3     function_IEEE_14   15.489796   19.632653   12.938776         NaN
#              function_IEEE_30   11.000000   17.000000   15.714286   15.928571
# config_4     function_IEEE_14   15.978261   15.913043   15.195652         NaN
#              function_IEEE_30   17.400000   17.600000   22.900000   22.800000
#
#                                best_var_7  best_var_8  best_var_9  execucao
# configuracao fitness_function
# config_1     function_IEEE_14         NaN         NaN         NaN  4.000000
#              function_IEEE_30   14.058442   13.857143   15.311688  4.564935
# config_2     function_IEEE_14         NaN         NaN         NaN  3.901961
#              function_IEEE_30   19.571429   19.642857   19.285714  4.000000
# config_3     function_IEEE_14         NaN         NaN         NaN  4.000000
#              function_IEEE_30   18.571429   16.571429   14.000000  4.000000
# config_4     function_IEEE_14         NaN         NaN         NaN  3.869565
#              function_IEEE_30   14.600000   12.500000   17.400000  3.400000

# %% [markdown]
# ## 2) Limpeza e Tratamento dos resultados consolidados

# %%
# --- Fluxo Corrigido ---

# Primeiro, precisamos da função que cria o molde
def renomear_colunas_from_map(df):
  mapa_inicial = {coluna: coluna for coluna in df.columns}
  return mapa_inicial

# 1. Crie o "molde" usando a função correta
mapa_molde = renomear_colunas_from_map(df_resultados_Agosto_Laucher_Streamlit)

# 2. Edite o molde como você já fez (esta parte está perfeita!)
mapa_molde['param_CROSSOVER'] = 'Crossover'
mapa_molde['param_MUTACAO'] = 'Mutação'
mapa_molde['param_NUM_GENERATIONS'] = 'Num_Gerações'
mapa_molde["param_IND_SIZE"] = 'tamanho_individuo'
# ...

# 3. Use o mapa já modificado para renomear, pode ser com o .rename() simples
results_df = df_resultados_Agosto_Laucher_Streamlit.rename(columns=mapa_molde)

# 4. Verifique o resultado
print("\nColunas renomeadas com sucesso!")
results_df.head(3)
# Out:
# Colunas renomeadas com sucesso!
#    Unnamed: 0                pasta_run configuracao  execucao  config_num  \
# 0           0  run_2025-08-29_01-11-02     config_1         1           1
# 1           1  run_2025-08-29_01-11-02     config_1         2           1
# 2           2  run_2025-08-29_01-11-02     config_1         3           1
#
#    Crossover  param_DELTA_MIN  tamanho_individuo  Mutação  Num_Gerações  ...  \
# 0        0.9                2                 10      0.9            20  ...
# 1        0.9                2                 10      0.9            20  ...
# 2        0.9                2                 10      0.9            20  ...
#
#    best_var_3  best_var_4  best_var_5  best_var_6  best_var_7  best_var_8  \
# 0          11          11          17         1.0        15.0        25.0
# 1          18          29          16        24.0        29.0         9.0
# 2          13          14          10         9.0         4.0        14.0
#
#    best_var_9  best_fitness  best_gen_idx  fitness_function
# 0        11.0     69.941159            18  function_IEEE_30
# 1        20.0     70.440283            17  function_IEEE_30
# 2         9.0     69.888380            17  function_IEEE_30
#
# [3 rows x 27 columns]

# %%
def aplicar_renomeacao(df, mapa_de_nomes, manter_apenas_mapeadas=False):
  """
  Renomeia colunas de um DataFrame e, opcionalmente, mantém apenas as
  colunas que foram especificadas no mapa de renomeação.

  Args:
    df (pd.DataFrame): O DataFrame original.
    mapa_de_nomes (dict): Dicionário com {nome_antigo: nome_novo}.
    manter_apenas_mapeadas (bool): Se True, descarta todas as outras colunas.
  
  Returns:
    pd.DataFrame: O DataFrame transformado.
  """
  # Primeiro, renomeia as colunas normalmente
  df_renomeado = df.rename(columns=mapa_de_nomes)

  # Agora, a nova lógica que você sugeriu:
  if manter_apenas_mapeadas:
    # Pega a lista dos novos nomes de coluna (os valores do dicionário)
    colunas_para_manter = list(mapa_de_nomes.values())
    
    # Retorna o DataFrame contendo APENAS essas colunas
    return df_renomeado[colunas_para_manter]
  else:
    # Se for False, retorna o DataFrame com todas as colunas (com os nomes trocados)
    return df_renomeado

# --- Como usar ---

# 1. Crie um mapa APENAS com as colunas que te interessam
mapa_essencial = {
      "pasta_run":"pasta_run",
    'config_num':"Número Config",
    'param_CROSSOVER': 'Crossover', # Pode mapear para o mesmo nome
    'param_MUTACAO': 'Mutação',
    'param_NUM_GENERATIONS': 'Número de Gerações',
    'param_POP_SIZE': "Tamanho População",
    "param_IND_SIZE": "Tamanho Individuo",
    "best_gen_idx": "Melhor Geração",
    
}


# Use o DataFrame que já tinha alguns nomes trocados, o df_novo
# Caso de uso 1: Apenas renomear 'melhor_fitness' para 'fitness_final'
df_alterado = aplicar_renomeacao(df_resultados_Agosto_Laucher_Streamlit, mapa_essencial,True)

print("--- Rodando com manter_apenas_mapeadas=True ---")
display(df_alterado.head())


print("Resultados gerais para cada configuração executada")
#df_resultado = pd.merge(df_alterado, best_variables_df, on='best_fitness')
df_resultado = pd.concat([df_alterado, best_variables_df], axis=1)
df_resultado
# Out:
# --- Rodando com manter_apenas_mapeadas=True ---
#                  pasta_run  Número Config  Crossover  Mutação  \
# 0  run_2025-08-29_01-11-02              1        0.9      0.9
# 1  run_2025-08-29_01-11-02              1        0.9      0.9
# 2  run_2025-08-29_01-11-02              1        0.9      0.9
# 3  run_2025-08-29_01-11-02              1        0.9      0.9
# 4  run_2025-08-29_01-11-02              1        0.9      0.9
#
#    Número de Gerações  Tamanho População  Tamanho Individuo  Melhor Geração
# 0                  20                 10                 10              18
# 1                  20                 10                 10              17
# 2                  20                 10                 10              17
# 3                  20                 10                 10              18
# 4                  20                 10                 10              15
# Resultados gerais para cada configuração executada
#                    pasta_run  Número Config  Crossover  Mutação  \
# 0    run_2025-08-29_01-11-02              1        0.9      0.9
# 1    run_2025-08-29_01-11-02              1        0.9      0.9
# 2    run_2025-08-29_01-11-02              1        0.9      0.9
# 3    run_2025-08-29_01-11-02              1        0.9      0.9
# 4    run_2025-08-29_01-11-02              1        0.9      0.9
# ..                       ...            ...        ...      ...
# 382  run_2025-08-31_20-10-40              1        0.9      0.9
# 383  run_2025-08-31_20-10-40              1        0.9      0.9
# 384  run_2025-08-31_20-10-40              1        0.9      0.9
# 385  run_2025-08-31_20-10-40              2        0.9      0.8
# 386  run_2025-08-31_20-10-40              2        0.9      0.8
#
#      Número de Gerações  Tamanho População  Tamanho Individuo  Melhor Geração  \
# 0                    20                 10                 10              18
# 1                    20                 10                 10              17
# 2                    20                 10                 10              17
# 3                    20                 10                 10              18
# 4                    20                 10                 10              15
# ..                  ...                ...                ...             ...
# 382                  20                 10                  5              18
# 383                  20                 10                  5              11
# 384                  20                 10                  5              18
# 385                  20                 10                  5              13
# 386                  20                 10                  5               9
#
#      best_fitness  best_var_1  ...  best_var_3  best_var_4  best_var_5  \
# 0       69.941159           9  ...          11          11          17
# 1       70.440283           2  ...          18          29          16
# 2       69.888380           3  ...          13          14          10
# 3       80.099917           1  ...           1          19          12
# 4       79.733306          29  ...          17          29          19
# ..            ...         ...  ...         ...         ...         ...
# 382     41.613011          10  ...          10          10          18
# 383     50.635405          31  ...          21          31          17
# 384     40.490471           0  ...           0           0           6
# 385     52.512700          15  ...          26          26          22
# 386     40.490471          31  ...          31          31          17
#
#      best_var_6  best_var_7  best_var_8  best_var_9  configuracao execucao  \
# 0           1.0        15.0        25.0        11.0      config_1        1
# 1          24.0        29.0         9.0        20.0      config_1        2
# 2           9.0         4.0        14.0         9.0      config_1        3
# 3          14.0        28.0        28.0        12.0      config_1        4
# 4          23.0        29.0        11.0        25.0      config_1        5
# ..          ...         ...         ...         ...           ...      ...
# 382         NaN         NaN         NaN         NaN      config_1        5
# 383         NaN         NaN         NaN         NaN      config_1        6
# 384         NaN         NaN         NaN         NaN      config_1        7
# 385         NaN         NaN         NaN         NaN      config_2        1
# 386         NaN         NaN         NaN         NaN      config_2        2
#
#      fitness_function
# 0    function_IEEE_30
# 1    function_IEEE_30
# 2    function_IEEE_30
# 3    function_IEEE_30
# 4    function_IEEE_30
# ..                ...
# 382  function_IEEE_14
# 383  function_IEEE_14
# 384  function_IEEE_14
# 385  function_IEEE_14
# 386  function_IEEE_14
#
# [387 rows x 21 columns]

# %% [markdown]
# ## Tratamento para o tempo de execução

# %%
import pandas as pd

def validate_time_laucher(df):
    """
    Calcula o tempo médio de execução para cada configuração por dia.

    A função executa os seguintes passos:
    1. Converte a coluna 'pasta_run' para um formato de data/hora.
    2. Cria uma coluna 'data' para agrupar as execuções por dia.
    3. Agrupa os dados por 'data' e 'configuracao'.
    4. Calcula a duração total das execuções para cada grupo.
    5. Conta o número de execuções em cada grupo.
    6. Calcula o tempo médio de execução e o adiciona como uma nova coluna.

    Args:
      df (pd.DataFrame): O DataFrame original contendo a coluna 'pasta_run'.

    Returns:
      pd.DataFrame: O DataFrame com as novas colunas de tempo e data.
    """
    df_calculado = df.copy()

    # Passo 1: Limpar a string e converter para datetime
    timestamp_str = df_calculado['pasta_run'].str.replace('run_', '')
    df_calculado['timestamp'] = pd.to_datetime(timestamp_str, format='%Y-%m-%d_%H-%M-%S')

    # Passo 2: Extrair a data para uma nova coluna
    df_calculado['data'] = df_calculado['timestamp'].dt.date

    # Passo 3, 4 e 5: Agrupar e calcular duração e contagem
    grupos = ['data', 'configuracao']
    tempo_min_grupo = df_calculado.groupby(grupos)['timestamp'].transform('min')
    tempo_max_grupo = df_calculado.groupby(grupos)['timestamp'].transform('max')
    duracao_total = tempo_max_grupo - tempo_min_grupo
    num_execucoes = df_calculado.groupby(grupos)['execucao'].transform('count')

    # Passo 6: Calcular o tempo médio
    df_calculado['tempo_medio_execucao'] = duracao_total / num_execucoes

    return df_calculado
#na coluna hora vc tem que fazer todos os horarios do dia um hora pela outra para saber o tempo de execucao de cada config e dividir pelo número de execuções e uma coluna data para saber o dia

df_resultado[["pasta_run"]].value_counts()


df_time = validate_time_laucher(df_resultado)
df_time
# Out:
#                    pasta_run  Número Config  Crossover  Mutação  \
# 0    run_2025-08-29_01-11-02              1        0.9      0.9
# 1    run_2025-08-29_01-11-02              1        0.9      0.9
# 2    run_2025-08-29_01-11-02              1        0.9      0.9
# 3    run_2025-08-29_01-11-02              1        0.9      0.9
# 4    run_2025-08-29_01-11-02              1        0.9      0.9
# ..                       ...            ...        ...      ...
# 382  run_2025-08-31_20-10-40              1        0.9      0.9
# 383  run_2025-08-31_20-10-40              1        0.9      0.9
# 384  run_2025-08-31_20-10-40              1        0.9      0.9
# 385  run_2025-08-31_20-10-40              2        0.9      0.8
# 386  run_2025-08-31_20-10-40              2        0.9      0.8
#
#      Número de Gerações  Tamanho População  Tamanho Individuo  Melhor Geração  \
# 0                    20                 10                 10              18
# 1                    20                 10                 10              17
# 2                    20                 10                 10              17
# 3                    20                 10                 10              18
# 4                    20                 10                 10              15
# ..                  ...                ...                ...             ...
# 382                  20                 10                  5              18
# 383                  20                 10                  5              11
# 384                  20                 10                  5              18
# 385                  20                 10                  5              13
# 386                  20                 10                  5               9
#
#      best_fitness  best_var_1  ...  best_var_6  best_var_7  best_var_8  \
# 0       69.941159           9  ...         1.0        15.0        25.0
# 1       70.440283           2  ...        24.0        29.0         9.0
# 2       69.888380           3  ...         9.0         4.0        14.0
# 3       80.099917           1  ...        14.0        28.0        28.0
# 4       79.733306          29  ...        23.0        29.0        11.0
# ..            ...         ...  ...         ...         ...         ...
# 382     41.613011          10  ...         NaN         NaN         NaN
# 383     50.635405          31  ...         NaN         NaN         NaN
# 384     40.490471           0  ...         NaN         NaN         NaN
# 385     52.512700          15  ...         NaN         NaN         NaN
# 386     40.490471          31  ...         NaN         NaN         NaN
#
#      best_var_9  configuracao  execucao  fitness_function           timestamp  \
# 0          11.0      config_1         1  function_IEEE_30 2025-08-29 01:11:02
# 1          20.0      config_1         2  function_IEEE_30 2025-08-29 01:11:02
# 2           9.0      config_1         3  function_IEEE_30 2025-08-29 01:11:02
# 3          12.0      config_1         4  function_IEEE_30 2025-08-29 01:11:02
# 4          25.0      config_1         5  function_IEEE_30 2025-08-29 01:11:02
# ..          ...           ...       ...               ...                 ...
# 382         NaN      config_1         5  function_IEEE_14 2025-08-31 20:10:40
# 383         NaN      config_1         6  function_IEEE_14 2025-08-31 20:10:40
# 384         NaN      config_1         7  function_IEEE_14 2025-08-31 20:10:40
# 385         NaN      config_2         1  function_IEEE_14 2025-08-31 20:10:40
# 386         NaN      config_2         2  function_IEEE_14 2025-08-31 20:10:40
#
#            data      tempo_medio_execucao
# 0    2025-08-29 0 days 00:08:18.896103896
# 1    2025-08-29 0 days 00:08:18.896103896
# 2    2025-08-29 0 days 00:08:18.896103896
# 3    2025-08-29 0 days 00:08:18.896103896
# 4    2025-08-29 0 days 00:08:18.896103896
# ..          ...                       ...
# 382  2025-08-31 0 days 00:05:01.897959183
# 383  2025-08-31 0 days 00:05:01.897959183
# 384  2025-08-31 0 days 00:05:01.897959183
# 385  2025-08-31 0 days 00:04:57.215686274
# 386  2025-08-31 0 days 00:04:57.215686274
#
# [387 rows x 24 columns]

# %%
import pandas as pd

def calcula_tempo_execucao(df):
    """
    Calcula o tempo médio de execução para cada grupo de configuração
    e adiciona como uma nova coluna no DataFrame.
    """
    # É uma boa prática trabalhar com uma cópia para não modificar o df original inesperadamente
    df_calculado = df.copy()

    # 1. Converte a coluna 'pasta_run' para um formato de data e hora (timestamp)
    # Primeiro removemos o "run_" do início do texto
    df_calculado['timestamp'] = df_calculado['pasta_run'].str.replace('run_', '')
    # Agora convertemos o texto restante para data/hora
    df_calculado['timestamp'] = pd.to_datetime(df_calculado['timestamp'], format='%Y-%m-%d_%H-%M-%S')

    # 2. Para cada grupo 'configuracao', calcula a duração total
    # A função .transform() é ótima aqui, pois ela realiza o cálculo por grupo
    # mas retorna um resultado com o mesmo tamanho do DataFrame original.
    tempo_min_grupo = df_calculado.groupby('configuracao')['timestamp'].transform('min')
    tempo_max_grupo = df_calculado.groupby('configuracao')['timestamp'].transform('max')

    duracao_total = tempo_max_grupo - tempo_min_grupo

    # 3. Conta o número de execuções em cada grupo
    num_execucoes = df_calculado.groupby('configuracao')['execucao'].transform('count')

    # 4. Calcula o tempo médio e cria a nova coluna
    # Verificamos se num_execucoes > 0 para evitar divisão por zero
    if not num_execucoes.empty:
      df_calculado['tempo_medio_execucao'] = duracao_total / num_execucoes
    else:
      df_calculado['tempo_medio_execucao'] = pd.NaT # preenche com nulo se não houver execuções

    return df_calculado

# %%
# --- Como usar tudo junto ---

# 1. Renomeie o DataFrame original
df_novo = df_resultado.rename(columns=mapa_molde)

# 2. Passe o DataFrame renomeado para a sua nova função
df_final = calcula_tempo_execucao(df_novo)

# 3. Veja o resultado!
# Usamos o .head() para ver as primeiras linhas e as novas colunas
print("\nDataFrame final com a coluna de tempo médio:")
display(df_final[['configuracao', 'execucao','timestamp', 'tempo_medio_execucao']].head())


# Supondo que seu DataFrame se chame 'df_final' e a coluna 'tempo_medio_execucao'
formatar_tempo = lambda td: f"{int(td.total_seconds() // 3600):02d}:{int((td.total_seconds() % 3600) // 60):02d}:{int(td.total_seconds() % 60):02d}"

# 2. Aplicamos essa função na coluna e criamos uma nova coluna formatada
df_final['tempo_formatado'] = df_final['tempo_medio_execucao'].apply(formatar_tempo)

# 3. Vamos ver o resultado
print("Coluna original vs. Coluna formatada:")
display(df_final[['tempo_medio_execucao', 'tempo_formatado']].head())

# A lambda pega o tempo (td), calcula o total de segundos,
# e formata em minutos (:02d) e segundos (:02d)
formatar_min_sec = lambda td: f"{int(td.total_seconds() // 60):02d}:{int(td.total_seconds() % 60):02d}"


#df_final['tempo_min_sec'] = df_final['tempo_medio_execucao'].apply(formatar_min_sec)

#print("Coluna original vs. Coluna formatada (MM:SS):")
#display(df_final[['tempo_medio_execucao', 'tempo_min_sec']].head())


print("DF Resultados Final")
df_final = df_final.drop(
  columns=['pasta_run', 'tempo_medio_execucao', 'timestamp',"Número Config"]
)

print("Resultados Finais tratados para o Dashboard")
df_final.to_excel("/home/pedrov12/Documentos/GitHub/Repopulation-With-Elite-Set/src/output/resultados.xlsx", index=False)

df_final
# Out:
# DataFrame final com a coluna de tempo médio:
#   configuracao  execucao           timestamp      tempo_medio_execucao
# 0     config_1         1 2025-08-29 01:11:02 0 days 00:19:48.068965517
# 1     config_1         2 2025-08-29 01:11:02 0 days 00:19:48.068965517
# 2     config_1         3 2025-08-29 01:11:02 0 days 00:19:48.068965517
# 3     config_1         4 2025-08-29 01:11:02 0 days 00:19:48.068965517
# 4     config_1         5 2025-08-29 01:11:02 0 days 00:19:48.068965517
# Coluna original vs. Coluna formatada:
#        tempo_medio_execucao tempo_formatado
# 0 0 days 00:19:48.068965517        00:19:48
# 1 0 days 00:19:48.068965517        00:19:48
# 2 0 days 00:19:48.068965517        00:19:48
# 3 0 days 00:19:48.068965517        00:19:48
# 4 0 days 00:19:48.068965517        00:19:48
# DF Resultados Final
# Resultados Finais tratados para o Dashboard
#      Crossover  Mutação  Número de Gerações  Tamanho População  \
# 0          0.9      0.9                  20                 10
# 1          0.9      0.9                  20                 10
# 2          0.9      0.9                  20                 10
# 3          0.9      0.9                  20                 10
# 4          0.9      0.9                  20                 10
# ..         ...      ...                 ...                ...
# 382        0.9      0.9                  20                 10
# 383        0.9      0.9                  20                 10
# 384        0.9      0.9                  20                 10
# 385        0.9      0.8                  20                 10
# 386        0.9      0.8                  20                 10
#
#      Tamanho Individuo  Melhor Geração  best_fitness  best_var_1  best_var_2  \
# 0                   10              18     69.941159           9          25
# 1                   10              17     70.440283           2          24
# 2                   10              17     69.888380           3           9
# 3                   10              18     80.099917           1          14
# 4                   10              15     79.733306          29          24
# ..                 ...             ...           ...         ...         ...
# 382                  5              18     41.613011          10          17
# 383                  5              11     50.635405          31           8
# 384                  5              18     40.490471           0          31
# 385                  5              13     52.512700          15           9
# 386                  5               9     40.490471          31           1
#
#      best_var_3  best_var_4  best_var_5  best_var_6  best_var_7  best_var_8  \
# 0            11          11          17         1.0        15.0        25.0
# 1            18          29          16        24.0        29.0         9.0
# 2            13          14          10         9.0         4.0        14.0
# 3             1          19          12        14.0        28.0        28.0
# 4            17          29          19        23.0        29.0        11.0
# ..          ...         ...         ...         ...         ...         ...
# 382          10          10          18         NaN         NaN         NaN
# 383          21          31          17         NaN         NaN         NaN
# 384           0           0           6         NaN         NaN         NaN
# 385          26          26          22         NaN         NaN         NaN
# 386          31          31          17         NaN         NaN         NaN
#
#      best_var_9 configuracao  execucao  fitness_function tempo_formatado
# 0          11.0     config_1         1  function_IEEE_30        00:19:48
# 1          20.0     config_1         2  function_IEEE_30        00:19:48
# 2           9.0     config_1         3  function_IEEE_30        00:19:48
# 3          12.0     config_1         4  function_IEEE_30        00:19:48
# 4          25.0     config_1         5  function_IEEE_30        00:19:48
# ..          ...          ...       ...               ...             ...
# 382         NaN     config_1         5  function_IEEE_14        00:19:48
# 383         NaN     config_1         6  function_IEEE_14        00:19:48
# 384         NaN     config_1         7  function_IEEE_14        00:19:48
# 385         NaN     config_2         1  function_IEEE_14        00:54:08
# 386         NaN     config_2         2  function_IEEE_14        00:54:08
#
# [387 rows x 20 columns]

# %%
#df_final[["tempo_formatado"]].astype(int).mean()

# %% [markdown]
# ## 3) Criação de tabelas e fazer seus UML com Diagrama de Classes com o uso do software

# %%
# tabela RCE


# Tabela AG-DEAP


# Tabela_Solutions

# %%
def separar_em_tabelas(df, coluna_criterio):
  """
  Separa um DataFrame em um dicionário de DataFrames menores,
  baseado nos valores únicos de uma coluna.

  Args:
    df (pd.DataFrame): O DataFrame a ser separado.
    coluna_criterio (str): O nome da coluna usada para agrupar.

  Returns:
    dict: Um dicionário onde as chaves são os valores da coluna
          e os valores são os DataFrames correspondentes.
  """
  tabelas_separadas = {}
  
  # O .groupby() cria um objeto que podemos percorrer com um loop.
  # Em cada passo, ele nos dá o nome do grupo e o DataFrame daquele grupo.
  for nome_do_grupo, df_do_grupo in df.groupby(coluna_criterio):
    # Usamos o nome do grupo como a chave do nosso dicionário
    # e guardamos o DataFrame correspondente como o valor.
    tabelas_separadas[nome_do_grupo] = df_do_grupo.copy() # .copy() evita avisos do pandas
  
  return tabelas_separadas

# --- Como usar a função ---
NUMERO_TABELS = 5 
# Vamos usar seu DataFrame final e separá-lo por 'configuracao'
dicionario_de_tabelas = separar_em_tabelas(df_final, 'configuracao')

# Agora, 'dicionario_de_tabelas' contém todas as suas tabelas separadas.
print("Tabelas criadas:", list(dicionario_de_tabelas.keys()))

for i in range(1,NUMERO_TABELS):
  df_config_1 = dicionario_de_tabelas[f'config_{i}']
  print(f"\nCabeçalho da tabela apenas para 'config_{i}':")
  display(df_config_1)
# Out:
# Tabelas criadas: ['config_1', 'config_2', 'config_3', 'config_4']
#
# Cabeçalho da tabela apenas para 'config_1':
#      Crossover  Mutação  Número de Gerações  Tamanho População  \
# 0          0.9      0.9                  20                 10
# 1          0.9      0.9                  20                 10
# 2          0.9      0.9                  20                 10
# 3          0.9      0.9                  20                 10
# 4          0.9      0.9                  20                 10
# ..         ...      ...                 ...                ...
# 380        0.9      0.9                  20                 10
# 381        0.9      0.9                  20                 10
# 382        0.9      0.9                  20                 10
# 383        0.9      0.9                  20                 10
# 384        0.9      0.9                  20                 10
#
#      Tamanho Individuo  Melhor Geração  best_fitness  best_var_1  best_var_2  \
# 0                   10              18     69.941159           9          25
# 1                   10              17     70.440283           2          24
# 2                   10              17     69.888380           3           9
# 3                   10              18     80.099917           1          14
# 4                   10              15     79.733306          29          24
# ..                 ...             ...           ...         ...         ...
# 380                  5              15     50.924353          11           6
# 381                  5              16     51.069368           0           0
# 382                  5              18     41.613011          10          17
# 383                  5              11     50.635405          31           8
# 384                  5              18     40.490471           0          31
#
#      best_var_3  best_var_4  best_var_5  best_var_6  best_var_7  best_var_8  \
# 0            11          11          17         1.0        15.0        25.0
# 1            18          29          16        24.0        29.0         9.0
# 2            13          14          10         9.0         4.0        14.0
# 3             1          19          12        14.0        28.0        28.0
# 4            17          29          19        23.0        29.0        11.0
# ..          ...         ...         ...         ...         ...         ...
# 380          11          25           7         NaN         NaN         NaN
# 381           0          25          20         NaN         NaN         NaN
# 382          10          10          18         NaN         NaN         NaN
# 383          21          31          17         NaN         NaN         NaN
# 384           0           0           6         NaN         NaN         NaN
#
#      best_var_9 configuracao  execucao  fitness_function tempo_formatado
# 0          11.0     config_1         1  function_IEEE_30        00:19:48
# 1          20.0     config_1         2  function_IEEE_30        00:19:48
# 2           9.0     config_1         3  function_IEEE_30        00:19:48
# 3          12.0     config_1         4  function_IEEE_30        00:19:48
# 4          25.0     config_1         5  function_IEEE_30        00:19:48
# ..          ...          ...       ...               ...             ...
# 380         NaN     config_1         3  function_IEEE_14        00:19:48
# 381         NaN     config_1         4  function_IEEE_14        00:19:48
# 382         NaN     config_1         5  function_IEEE_14        00:19:48
# 383         NaN     config_1         6  function_IEEE_14        00:19:48
# 384         NaN     config_1         7  function_IEEE_14        00:19:48
#
# [203 rows x 20 columns]
# Cabeçalho da tabela apenas para 'config_2':
#      Crossover  Mutação  Número de Gerações  Tamanho População  \
# 56         0.9      0.5                  20                 10
# 57         0.9      0.5                  20                 10
# 58         0.9      0.5                  20                 10
# 59         0.9      0.5                  20                 10
# 60         0.9      0.5                  20                 10
# ..         ...      ...                 ...                ...
# 361        0.9      0.8                  20                 10
# 362        0.9      0.8                  20                 10
# 363        0.9      0.8                  20                 10
# 385        0.9      0.8                  20                 10
# 386        0.9      0.8                  20                 10
#
#      Tamanho Individuo  Melhor Geração  best_fitness  best_var_1  best_var_2  \
# 56                  10              15     71.039367          31          18
# 57                  10              19     70.295020          23          29
# 58                  10              12     90.617660          25           8
# 59                  10               8     80.108155          26          17
# 60                  10              18     76.106688          15          10
# ..                 ...             ...           ...         ...         ...
# 361                  5              18     42.061447          13          19
# 362                  5              19     62.761874           7          16
# 363                  5              10     54.431039          16          30
# 385                  5              13     52.512700          15           9
# 386                  5               9     40.490471          31           1
#
#      best_var_3  best_var_4  best_var_5  best_var_6  best_var_7  best_var_8  \
# 56           31          24          30        13.0        24.0         8.0
# 57           28          23          29         0.0        11.0        29.0
# 58           31           8          21        25.0         2.0        30.0
# 59           17          27          18         9.0        26.0         2.0
# 60           10          26          26        10.0        26.0         6.0
# ..          ...         ...         ...         ...         ...         ...
# 361          13          13           4         NaN         NaN         NaN
# 362          21          31          16         NaN         NaN         NaN
# 363           9           9           4         NaN         NaN         NaN
# 385          26          26          22         NaN         NaN         NaN
# 386          31          31          17         NaN         NaN         NaN
#
#      best_var_9 configuracao  execucao  fitness_function tempo_formatado
# 56         30.0     config_2         1  function_IEEE_30        00:54:08
# 57         29.0     config_2         2  function_IEEE_30        00:54:08
# 58         27.0     config_2         3  function_IEEE_30        00:54:08
# 59         18.0     config_2         4  function_IEEE_30        00:54:08
# 60         26.0     config_2         5  function_IEEE_30        00:54:08
# ..          ...          ...       ...               ...             ...
# 361         NaN     config_2         5  function_IEEE_14        00:54:08
# 362         NaN     config_2         6  function_IEEE_14        00:54:08
# 363         NaN     config_2         7  function_IEEE_14        00:54:08
# 385         NaN     config_2         1  function_IEEE_14        00:54:08
# 386         NaN     config_2         2  function_IEEE_14        00:54:08
#
# [65 rows x 20 columns]
# Cabeçalho da tabela apenas para 'config_3':
#      Crossover  Mutação  Número de Gerações  Tamanho População  \
# 63         0.9      0.5                  20                 10
# 64         0.9      0.5                  20                 10
# 65         0.9      0.5                  20                 10
# 66         0.9      0.5                  20                 10
# 67         0.9      0.5                  20                 10
# ..         ...      ...                 ...                ...
# 366        0.9      0.1                  20                 10
# 367        0.9      0.1                  20                 10
# 368        0.9      0.1                  20                 10
# 369        0.9      0.1                  20                 10
# 370        0.9      0.1                  20                 10
#
#      Tamanho Individuo  Melhor Geração  best_fitness  best_var_1  best_var_2  \
# 63                  10               2     79.603209           7          26
# 64                  10              12     80.657680          10           7
# 65                  10              14     94.351913          28          28
# 66                  10              14     91.221560          11          30
# 67                  10               7     85.920823           1          21
# ..                 ...             ...           ...         ...         ...
# 366                  5              10     40.490471          31           2
# 367                  5               0     51.083840          28          23
# 368                  5              15     61.544031          12          22
# 369                  5              11     53.204404          16           4
# 370                  5               4     51.918819           3          10
#
#      best_var_3  best_var_4  best_var_5  best_var_6  best_var_7  best_var_8  \
# 63            7          20           8         8.0        26.0        31.0
# 64            3           3          12         9.0        14.0        26.0
# 65           13          30          15        21.0        28.0        29.0
# 66           11          17           6         9.0         4.0         9.0
# 67            1          28          22        22.0        12.0        29.0
# ..          ...         ...         ...         ...         ...         ...
# 366          31          31           3         NaN         NaN         NaN
# 367          14          28           1         NaN         NaN         NaN
# 368           0          12           0         NaN         NaN         NaN
# 369          16          25          25         NaN         NaN         NaN
# 370          18           3          20         NaN         NaN         NaN
#
#      best_var_9 configuracao  execucao  fitness_function tempo_formatado
# 63         15.0     config_3         1  function_IEEE_30        00:55:22
# 64         16.0     config_3         2  function_IEEE_30        00:55:22
# 65         29.0     config_3         3  function_IEEE_30        00:55:22
# 66          6.0     config_3         4  function_IEEE_30        00:55:22
# 67          3.0     config_3         5  function_IEEE_30        00:55:22
# ..          ...          ...       ...               ...             ...
# 366         NaN     config_3         3  function_IEEE_14        00:55:22
# 367         NaN     config_3         4  function_IEEE_14        00:55:22
# 368         NaN     config_3         5  function_IEEE_14        00:55:22
# 369         NaN     config_3         6  function_IEEE_14        00:55:22
# 370         NaN     config_3         7  function_IEEE_14        00:55:22
#
# [63 rows x 20 columns]
# Cabeçalho da tabela apenas para 'config_4':
#      Crossover  Mutação  Número de Gerações  Tamanho População  \
# 70         0.9     0.50                  20                 10
# 71         0.9     0.50                  20                 10
# 72         0.9     0.50                  20                 10
# 185        0.9     0.20                  20                 10
# 186        0.9     0.20                  20                 10
# 187        0.9     0.20                  20                 10
# 188        0.9     0.20                  20                 10
# 189        0.9     0.20                  20                 10
# 190        0.9     0.20                  20                 10
# 191        0.9     0.20                  20                 10
# 206        0.9     0.05                  20                 10
# 207        0.9     0.05                  20                 10
# 208        0.9     0.05                  20                 10
# 209        0.9     0.05                  20                 10
# 231        0.9     0.05                  20                 10
# 232        0.9     0.05                  20                 10
# 233        0.9     0.05                  20                 10
# 234        0.9     0.05                  20                 10
# 235        0.9     0.05                  20                 10
# 236        0.9     0.05                  20                 10
# 237        0.9     0.05                  20                 10
# 259        0.9     0.05                  20                 10
# 260        0.9     0.05                  20                 10
# 261        0.9     0.05                  20                 10
# 262        0.9     0.05                  20                 10
# 263        0.9     0.05                  20                 10
# 264        0.9     0.05                  20                 10
# 265        0.9     0.05                  20                 10
# 287        0.9     0.05                  20                 10
# 288        0.9     0.05                  20                 10
# 289        0.9     0.05                  20                 10
# 290        0.9     0.05                  20                 10
# 291        0.9     0.05                  20                 10
# 292        0.9     0.05                  20                 10
# 293        0.9     0.05                  20                 10
# 315        0.9     0.05                  20                 10
# 316        0.9     0.05                  20                 10
# 317        0.9     0.05                  20                 10
# 318        0.9     0.05                  20                 10
# 319        0.9     0.05                  20                 10
# 320        0.9     0.05                  20                 10
# 321        0.9     0.05                  20                 10
# 343        0.9     0.05                  20                 10
# 344        0.9     0.05                  20                 10
# 345        0.9     0.05                  20                 10
# 346        0.9     0.05                  20                 10
# 347        0.9     0.05                  20                 10
# 348        0.9     0.05                  20                 10
# 349        0.9     0.05                  20                 10
# 371        0.9     0.05                  20                 10
# 372        0.9     0.05                  20                 10
# 373        0.9     0.05                  20                 10
# 374        0.9     0.05                  20                 10
# 375        0.9     0.05                  20                 10
# 376        0.9     0.05                  20                 10
# 377        0.9     0.05                  20                 10
#
#      Tamanho Individuo  Melhor Geração  best_fitness  best_var_1  best_var_2  \
# 70                  10              15     89.956640           8          28
# 71                  10              17     70.720149          24          25
# 72                  10              16     64.365835          10          25
# 185                 10               8    100.628528          27          10
# 186                 10               6    100.658530          12           1
# 187                 10              15     90.962927           0          24
# 188                 10              11     82.661917          13          26
# 189                 10              15     89.972973          15          14
# 190                 10              17     99.768557          27          22
# 191                 10              11     71.829762          13           1
# 206                  5              11     57.158251          21           2
# 207                  5              11     53.632188          23          30
# 208                  5              10     63.784168          28          10
# 209                  5              17     52.512700          15          31
# 231                  5              15     63.363016          31          13
# 232                  5              11     41.613011           6          13
# 233                  5              13     62.914581          20           8
# 234                  5              10     64.165303          31          13
# 235                  5              19     65.493335          19          27
# 236                  5              19     52.512700          20           3
# 237                  5              10     53.632188          15          16
# 259                  5              11     52.367254           1          30
# 260                  5              10     53.311551          13           7
# 261                  5              10     65.095276          27          27
# 262                  5               1     51.083840          25           7
# 263                  5              19     68.302382          21           4
# 264                  5              10     53.732198          21           1
# 265                  5               0     56.253268          11          27
# 287                  5              19     52.457309          12           1
# 288                  5              19     61.150145          26          12
# 289                  5              13     53.204404          13           8
# 290                  5               9     63.210309          27          27
# 291                  5              11     63.263155           4          24
# 292                  5              19     62.038731          10          20
# 293                  5              10     64.165303           0          22
# 315                  5              12     52.861275          17           0
# 316                  5              13     51.024213          19          26
# 317                  5              11     52.106893          17          25
# 318                  5              18     61.150145          28           9
# 319                  5               9     59.433590          25          20
# 320                  5              10     53.632188          13          28
# 321                  5               2     51.024213          20          10
# 343                  5               9     54.233331          30          19
# 344                  5              14     52.457309          11          21
# 345                  5              11     54.875852           5           6
# 346                  5               1     58.698990          28          27
# 347                  5              19     50.635405          27          13
# 348                  5              19     50.983980          25          10
# 349                  5              14     53.169541           5          15
# 371                  5               0     52.450821           6          12
# 372                  5              11     49.583885          16          25
# 373                  5              12     52.457309          18          30
# 374                  5              10     52.512700          21           2
# 375                  5               3     51.417235          12          16
# 376                  5              12     52.512700           0           0
# 377                  5               3     62.761874          13          13
#
#      best_var_3  best_var_4  best_var_5  best_var_6  best_var_7  best_var_8  \
# 70           20           8          29        28.0         7.0         1.0
# 71           13           2          31         8.0         2.0        25.0
# 72           24          24          26        25.0        10.0        30.0
# 185          27          25          14        14.0         8.0         1.0
# 186          12           6          17        23.0        11.0         2.0
# 187           0           8          26        20.0        28.0        29.0
# 188          25          31          24        28.0        13.0         2.0
# 189          10          27          16        22.0        27.0         3.0
# 190          13          24          15        30.0        27.0         1.0
# 191          30          21          31        30.0        13.0        31.0
# 206          21          12          23         NaN         NaN         NaN
# 207          12          12          18         NaN         NaN         NaN
# 208          18          28          17         NaN         NaN         NaN
# 209          25          25          17         NaN         NaN         NaN
# 231          18          25           2         NaN         NaN         NaN
# 232           6           6          21         NaN         NaN         NaN
# 233          13          28          20         NaN         NaN         NaN
# 234           2          25          20         NaN         NaN         NaN
# 235          19           2          20         NaN         NaN         NaN
# 236          27          27          22         NaN         NaN         NaN
# 237           5           5          22         NaN         NaN         NaN
# 259          18           1          14         NaN         NaN         NaN
# 260          31          31           1         NaN         NaN         NaN
# 261          11           0          17         NaN         NaN         NaN
# 262          17          25          13         NaN         NaN         NaN
# 263           1           1          17         NaN         NaN         NaN
# 264          21           1          13         NaN         NaN         NaN
# 265          17          11          13         NaN         NaN         NaN
# 287          12           6          28         NaN         NaN         NaN
# 288          18          18          13         NaN         NaN         NaN
# 289          13          28          30         NaN         NaN         NaN
# 290          19           2           9         NaN         NaN         NaN
# 291          13          30           6         NaN         NaN         NaN
# 292          10          20          29         NaN         NaN         NaN
# 293           7          31          15         NaN         NaN         NaN
# 315          28          28           1         NaN         NaN         NaN
# 316          19          31           6         NaN         NaN         NaN
# 317          17           0          10         NaN         NaN         NaN
# 318          17          17          10         NaN         NaN         NaN
# 319          25          11           5         NaN         NaN         NaN
# 320           3           3          23         NaN         NaN         NaN
# 321          20          28           3         NaN         NaN         NaN
# 343           1           1          10         NaN         NaN         NaN
# 344          11           1          29         NaN         NaN         NaN
# 345          20           5          14         NaN         NaN         NaN
# 346          28           5          28         NaN         NaN         NaN
# 347          19          27          19         NaN         NaN         NaN
# 348          15          25          10         NaN         NaN         NaN
# 349          14           5          23         NaN         NaN         NaN
# 371           6          24           0         NaN         NaN         NaN
# 372          16          16           5         NaN         NaN         NaN
# 373          18           0          24         NaN         NaN         NaN
# 374          27          27          11         NaN         NaN         NaN
# 375          12          26          12         NaN         NaN         NaN
# 376          25          25          14         NaN         NaN         NaN
# 377          20          27          22         NaN         NaN         NaN
#
#      best_var_9 configuracao  execucao  fitness_function tempo_formatado
# 70          7.0     config_4         1  function_IEEE_30        01:02:18
# 71         20.0     config_4         2  function_IEEE_30        01:02:18
# 72         26.0     config_4         3  function_IEEE_30        01:02:18
# 185        21.0     config_4         1  function_IEEE_30        01:02:18
# 186        14.0     config_4         2  function_IEEE_30        01:02:18
# 187        20.0     config_4         3  function_IEEE_30        01:02:18
# 188        24.0     config_4         4  function_IEEE_30        01:02:18
# 189        15.0     config_4         5  function_IEEE_30        01:02:18
# 190        20.0     config_4         6  function_IEEE_30        01:02:18
# 191         7.0     config_4         7  function_IEEE_30        01:02:18
# 206         NaN     config_4         1  function_IEEE_14        01:02:18
# 207         NaN     config_4         2  function_IEEE_14        01:02:18
# 208         NaN     config_4         3  function_IEEE_14        01:02:18
# 209         NaN     config_4         4  function_IEEE_14        01:02:18
# 231         NaN     config_4         1  function_IEEE_14        01:02:18
# 232         NaN     config_4         2  function_IEEE_14        01:02:18
# 233         NaN     config_4         3  function_IEEE_14        01:02:18
# 234         NaN     config_4         4  function_IEEE_14        01:02:18
# 235         NaN     config_4         5  function_IEEE_14        01:02:18
# 236         NaN     config_4         6  function_IEEE_14        01:02:18
# 237         NaN     config_4         7  function_IEEE_14        01:02:18
# 259         NaN     config_4         1  function_IEEE_14        01:02:18
# 260         NaN     config_4         2  function_IEEE_14        01:02:18
# 261         NaN     config_4         3  function_IEEE_14        01:02:18
# 262         NaN     config_4         4  function_IEEE_14        01:02:18
# 263         NaN     config_4         5  function_IEEE_14        01:02:18
# 264         NaN     config_4         6  function_IEEE_14        01:02:18
# 265         NaN     config_4         7  function_IEEE_14        01:02:18
# 287         NaN     config_4         1  function_IEEE_14        01:02:18
# 288         NaN     config_4         2  function_IEEE_14        01:02:18
# 289         NaN     config_4         3  function_IEEE_14        01:02:18
# 290         NaN     config_4         4  function_IEEE_14        01:02:18
# 291         NaN     config_4         5  function_IEEE_14        01:02:18
# 292         NaN     config_4         6  function_IEEE_14        01:02:18
# 293         NaN     config_4         7  function_IEEE_14        01:02:18
# 315         NaN     config_4         1  function_IEEE_14        01:02:18
# 316         NaN     config_4         2  function_IEEE_14        01:02:18
# 317         NaN     config_4         3  function_IEEE_14        01:02:18
# 318         NaN     config_4         4  function_IEEE_14        01:02:18
# 319         NaN     config_4         5  function_IEEE_14        01:02:18
# 320         NaN     config_4         6  function_IEEE_14        01:02:18
# 321         NaN     config_4         7  function_IEEE_14        01:02:18
# 343         NaN     config_4         1  function_IEEE_14        01:02:18
# 344         NaN     config_4         2  function_IEEE_14        01:02:18
# 345         NaN     config_4         3  function_IEEE_14        01:02:18
# 346         NaN     config_4         4  function_IEEE_14        01:02:18
# 347         NaN     config_4         5  function_IEEE_14        01:02:18
# 348         NaN     config_4         6  function_IEEE_14        01:02:18
# 349         NaN     config_4         7  function_IEEE_14        01:02:18
# 371         NaN     config_4         1  function_IEEE_14        01:02:18
# 372         NaN     config_4         2  function_IEEE_14        01:02:18
# 373         NaN     config_4         3  function_IEEE_14        01:02:18
# 374         NaN     config_4         4  function_IEEE_14        01:02:18
# 375         NaN     config_4         5  function_IEEE_14        01:02:18
# 376         NaN     config_4         6  function_IEEE_14        01:02:18
# 377         NaN     config_4         7  function_IEEE_14        01:02:18

# %% [markdown]
# ## 3) Análisando os parametros AG

# %%
def display_value_counts(df, column_name):
    return df[column_name].value_counts()


print("Total de execuções pelo Laucher.py", df_final.shape[0])
print("Colunas do DataFrame",df_final.columns)

display(display_value_counts(df_final, 'Crossover'))
display(display_value_counts(df_final, 'Mutação'))
display(display_value_counts(df_final, 'Número de Gerações'))
display(display_value_counts(df_final, 'Tamanho População'))
display(display_value_counts(df_final, 'Melhor Geração'))
# Out:
# Total de execuções pelo Laucher.py 387
# Colunas do DataFrame Index(['Crossover', 'Mutação', 'Número de Gerações', 'Tamanho População',
#        'Tamanho Individuo', 'Melhor Geração', 'best_fitness', 'best_var_1',
#        'best_var_2', 'best_var_3', 'best_var_4', 'best_var_5', 'best_var_6',
#        'best_var_7', 'best_var_8', 'best_var_9', 'configuracao', 'execucao',
#        'fitness_function', 'tempo_formatado'],
#       dtype='object')
# Crossover
# 0.9    387
# Name: count, dtype: int64
# Mutação
# 0.50    114
# 0.90    106
# 0.80     58
# 0.10     56
# 0.05     46
# 0.20      7
# Name: count, dtype: int64
# Número de Gerações
# 20    387
# Name: count, dtype: int64
# Tamanho População
# 10    387
# Name: count, dtype: int64
# Melhor Geração
#  19    58
#  17    37
#  18    37
#  16    34
#  15    32
#  14    31
#  11    27
#  13    24
#  12    23
#  10    19
#  9     13
#  8     12
#  6      6
#  7      6
#  2      5
#  1      5
#  5      4
#  3      4
#  0      4
# -1      3
#  4      3
# Name: count, dtype: int64

# %% [markdown]
# ## 4) Análisando os parametros RCE

# %% [markdown]
# ## 5) Gráficos e tabelas resumos interessantes

# %% [markdown]
# ## 6) Dashboard template para Análise de dados (ALURA)
