# %% [markdown]
# # Create Networks - Advanced

# %% [markdown]
# This tutorial shows how to create a more complex pandapower network step by step. The network includes every element which is availiable in the pandapower framework.
#
# The final network looks like this:
#
# <img src="pics/example_network.png" width="50%">

# %% [markdown]
# The structural information about this network are stored in csv tables in the example_advanced folder.
#
# For a better overview the creation of the individual components is divided in three steps. Each step handles one of the three voltage levels: high, medium and low voltage. We star by initializing an empty pandapower network:

# %%
#!pip install pandas pandapower
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-3.0.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting pandapower
#   Downloading pandapower-3.4.0-py3-none-any.whl.metadata (9.1 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pedrov12\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting networkx~=3.4 (from pandapower)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting scipy<1.17 (from pandapower)
#   Downloading scipy-1.16.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting packaging~=25.0 (from pandapower)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting tqdm~=4.67 (from pandapower)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting deepdiff~=8.6 (from pandapower)
#   Using cached deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting geojson~=3.2 (from pandapower)
#   Using cached geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting typing_extensions~=4.9 (from pandapower)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pandera~=0.26.1 (from pandapower)
#   Using cached pandera-0.26.1-py3-none-any.whl.metadata (10 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff~=8.6->pandapower)
#   Using cached orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting pydantic (from pandera~=0.26.1->pandapower)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typeguard (from pandera~=0.26.1->pandapower)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting typing_inspect>=0.6.0 (from pandera~=0.26.1->pandapower)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: colorama in c:\users\pedrov12\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm~=4.67->pandapower) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\pedrov12\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing_inspect>=0.6.0->pandera~=0.26.1->pandapower)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->pandera~=0.26.1->pandapower)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->pandera~=0.26.1->pandapower)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic->pandera~=0.26.1->pandapower)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading pandapower-3.4.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.6/5.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.5 MB 8.0 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 6.0 MB/s  0:00:00
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------------------- -------------- 7.1/11.0 MB 35.5 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 39.1 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 39.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 13.3 MB/s  0:00:00
# Using cached deepdiff-8.6.1-py3-none-any.whl (91 kB)
# Using cached geojson-3.2.0-py3-none-any.whl (15 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Downloading numpy-2.3.5-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------  12.6/12.8 MB 70.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 70.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 28.4 MB/s  0:00:00
# Using cached orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pandera-0.26.1-py3-none-any.whl (292 kB)
# Downloading scipy-1.16.3-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ----- ---------------------------------- 5.2/38.5 MB 32.3 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/38.5 MB 21.7 MB/s eta 0:00:02
#    -------- ------------------------------- 8.4/38.5 MB 15.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.5/38.5 MB 13.9 MB/s eta 0:00:02
#    -------------- ------------------------- 13.6/38.5 MB 14.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.7/38.5 MB 12.6 MB/s eta 0:00:02
#    -------------------------- ------------- 25.2/38.5 MB 17.1 MB/s eta 0:00:01
#    --------------------------- ------------ 26.2/38.5 MB 16.6 MB/s eta 0:00:01
#    ------------------------------- -------- 30.4/38.5 MB 16.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.5 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 12.5 MB/s  0:00:03
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------------ --- 1.8/2.0 MB 118.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.0 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Installing collected packages: pytz, tzdata, typing_extensions, tqdm, packaging, orderly-set, numpy, networkx, mypy-extensions, geojson, annotated-types, typing-inspection, typing_inspect, typeguard, scipy, pydantic-core, pandas, deepdiff, pydantic, pandera, pandapower
#
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    ----------------------------------------  0/21 [pytz]
#    - --------------------------------------  1/21 [tzdata]
#    - --------------------------------------  1/21 [tzdata]
#    - --------------------------------------  1/21 [tzdata]
#    - --------------------------------------  1/21 [tzdata]
#    - --------------------------------------  1/21 [tzdata]
#    --- ------------------------------------  2/21 [typing_extensions]
#    --- ------------------------------------  2/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#    ----- ----------------------------------  3/21 [tqdm]
#   Attempting uninstall: packaging
#    ----- ----------------------------------  3/21 [tqdm]
#     Found existing installation: packaging 26.0
#    ----- ----------------------------------  3/21 [tqdm]
#     Uninstalling packaging-26.0:
#    ----- ----------------------------------  3/21 [tqdm]
#       Successfully uninstalled packaging-26.0
#    ----- ----------------------------------  3/21 [tqdm]
#    ------- --------------------------------  4/21 [packaging]
#    ------- --------------------------------  4/21 [packaging]
#    ------- --------------------------------  4/21 [packaging]
#    ------- --------------------------------  4/21 [packaging]
#    ------- --------------------------------  4/21 [packaging]
#    ------- --------------------------------  4/21 [packaging]
#    --------- ------------------------------  5/21 [orderly-set]
#    --------- ------------------------------  5/21 [orderly-set]
#    --------- ------------------------------  5/21 [orderly-set]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ----------- ----------------------------  6/21 [numpy]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    ------------- --------------------------  7/21 [networkx]
#    --------------- ------------------------  8/21 [mypy-extensions]
#    ----------------- ----------------------  9/21 [geojson]
#    ----------------- ----------------------  9/21 [geojson]
#    ----------------- ----------------------  9/21 [geojson]
#    ----------------- ----------------------  9/21 [geojson]
#    ----------------- ----------------------  9/21 [geojson]
#    ------------------- -------------------- 10/21 [annotated-types]
#    ------------------- -------------------- 10/21 [annotated-types]
#    -------------------- ------------------- 11/21 [typing-inspection]
#    ---------------------- ----------------- 12/21 [typing_inspect]
#    ---------------------- ----------------- 12/21 [typing_inspect]
#    ------------------------ --------------- 13/21 [typeguard]
#    ------------------------ --------------- 13/21 [typeguard]
#    ------------------------ --------------- 13/21 [typeguard]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    -------------------------- ------------- 14/21 [scipy]
#    ---------------------------- ----------- 15/21 [pydantic-core]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    -------------------------------- ------- 17/21 [deepdiff]
#    -------------------------------- ------- 17/21 [deepdiff]
#    -------------------------------- ------- 17/21 [deepdiff]
#    -------------------------------- ------- 17/21 [deepdiff]
#    -------------------------------- ------- 17/21 [deepdiff]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ---------------------------------- ----- 18/21 [pydantic]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    ------------------------------------ --- 19/21 [pandera]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    -------------------------------------- - 20/21 [pandapower]
#    ---------------------------------------- 21/21 [pandapower]
#
# Successfully installed annotated-types-0.7.0 deepdiff-8.6.1 geojson-3.2.0 mypy-extensions-1.1.0 networkx-3.6.1 numpy-2.3.5 orderly-set-5.5.0 packaging-25.0 pandapower-3.4.0 pandas-2.3.3 pandera-0.26.1 pydantic-2.12.5 pydantic-core-2.41.5 pytz-2026.1.post1 scipy-1.16.3 tqdm-4.67.3 typeguard-4.5.1 typing-inspection-0.4.2 typing_extensions-4.15.0 typing_inspect-0.9.0 tzdata-2025.3
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\pedrov12\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

from pandapower.create import (
    create_empty_network,
    create_ext_grid,
    create_bus,
    create_line,
    create_transformer_from_parameters,
    create_transformer3w_from_parameters,
    create_switch,
    create_gen,
    create_load,
    create_sgen,
    create_shunt,
    create_xward,
    create_impedance
)
from pandapower.run import runpp
from pandapower.toolbox.element_selection import get_element_index
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#create an empty network
net = create_empty_network()
net
# Out:
# This pandapower network is empty

# %% [markdown]
# ## High voltage level

# %% [markdown]
# ### Buses
#
# <img src="pics/example_network_buses_hv_detail.png" width="50%">

# %% [markdown]
# There are two 380 kV and five 110 kV busbars (type="b"). The 380/110 kV substation is modeled in detail with all nodes and switches, which is why we need additional nodes (type="b") to connect the switches.

# %%
# Double busbar
create_bus(net, name='Double Busbar 1', vn_kv=380, type='b')
create_bus(net, name='Double Busbar 2', vn_kv=380, type='b')
for i in range(10):
    create_bus(net, name='Bus DB T%s' % i, vn_kv=380, type='n')
for i in range(1, 5):
    create_bus(net, name='Bus DB %s' % i, vn_kv=380, type='n')

# Single busbar
create_bus(net, name='Single Busbar', vn_kv=110, type='b')
for i in range(1, 6):
    create_bus(net, name='Bus SB %s' % i, vn_kv=110, type='n')
for i in range(1, 6):
    for j in [1, 2]:
        create_bus(net, name='Bus SB T%s.%s' % (i, j), vn_kv=110, type='n')

# Remaining buses
for i in range(1, 5):
    create_bus(net, name=f'Bus HV{i}', vn_kv=110, type='n')

bus1 = get_element_index(net, "bus", "Bus HV1")


# show bustable
net.bus
# Out:
#                name  vn_kv type  zone  in_service   geo
# 0   Double Busbar 1  380.0    b  None        True  None
# 1   Double Busbar 2  380.0    b  None        True  None
# 2         Bus DB T0  380.0    n  None        True  None
# 3         Bus DB T1  380.0    n  None        True  None
# 4         Bus DB T2  380.0    n  None        True  None
# 5         Bus DB T3  380.0    n  None        True  None
# 6         Bus DB T4  380.0    n  None        True  None
# 7         Bus DB T5  380.0    n  None        True  None
# 8         Bus DB T6  380.0    n  None        True  None
# 9         Bus DB T7  380.0    n  None        True  None
# 10        Bus DB T8  380.0    n  None        True  None
# 11        Bus DB T9  380.0    n  None        True  None
# 12         Bus DB 1  380.0    n  None        True  None
# 13         Bus DB 2  380.0    n  None        True  None
# 14         Bus DB 3  380.0    n  None        True  None
# 15         Bus DB 4  380.0    n  None        True  None
# 16    Single Busbar  110.0    b  None        True  None
# 17         Bus SB 1  110.0    n  None        True  None
# 18         Bus SB 2  110.0    n  None        True  None
# 19         Bus SB 3  110.0    n  None        True  None
# 20         Bus SB 4  110.0    n  None        True  None
# 21         Bus SB 5  110.0    n  None        True  None
# 22      Bus SB T1.1  110.0    n  None        True  None
# 23      Bus SB T1.2  110.0    n  None        True  None
# 24      Bus SB T2.1  110.0    n  None        True  None
# 25      Bus SB T2.2  110.0    n  None        True  None
# 26      Bus SB T3.1  110.0    n  None        True  None
# 27      Bus SB T3.2  110.0    n  None        True  None
# 28      Bus SB T4.1  110.0    n  None        True  None
# 29      Bus SB T4.2  110.0    n  None        True  None
# 30      Bus SB T5.1  110.0    n  None        True  None
# 31      Bus SB T5.2  110.0    n  None        True  None
# 32          Bus HV1  110.0    n  None        True  None
# 33          Bus HV2  110.0    n  None        True  None
# 34          Bus HV3  110.0    n  None        True  None
# 35          Bus HV4  110.0    n  None        True  None

# %% [markdown]
# ### Lines
#
# <img src="pics/example_network_lines_hv.png" width="40%">

# %% [markdown]
# The information about the 6 HV lines are stored in a csv file that we load from the hard drive:

# %%
hv_lines = pd.read_csv('example_advanced/hv_lines.csv', sep=';', header=0, decimal=',')
hv_lines
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hv_lines = pd.read_csv('example_advanced/hv_lines.csv', sep=';', header=0, decimal=',')
#       2 hv_lines
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example_advanced/hv_lines.csv'

# %% [markdown]
# and use to create all lines:

# %%
# create lines
for _, hv_line in hv_lines.iterrows():
        from_bus = get_element_index(net, "bus", hv_line.from_bus)
        to_bus = get_element_index(net, "bus", hv_line.to_bus)
        create_line(net, from_bus, to_bus, length_km=hv_line.length,std_type=hv_line.std_type, name=hv_line.line_name, parallel=hv_line.parallel)

# show line table
net.line

# %% [markdown]
# ### Transformer
#
# <img src="pics/example_network_trafos_hv.png" width="40%">

# %% [markdown]
# The 380/110 kV transformer connects the buses "Bus DB 1" and "Bus DB 2". We use the get_element_index function from the pandapower toolbox to find the bus indices of the buses with these names and create a transformer by directly specifying the parameters:

# %%
hv_bus = get_element_index(net, "bus", "Bus DB 2")
lv_bus = get_element_index(net, "bus", "Bus SB 1")
create_transformer_from_parameters(net, hv_bus, lv_bus, sn_mva=300, vn_hv_kv=380, vn_lv_kv=110, vkr_percent=0.06,
                                      vk_percent=8, pfe_kw=0, i0_percent=0, tp_pos=0, shift_degree=0, name='EHV-HV-Trafo')

net.trafo # show trafo table

# %% [markdown]
# ### Switches
#
# <img src="pics/example_network_switches_hv.png" width="60%">

# %% [markdown]
# Now we create the switches to connect the buses in the transformer station. The switch configuration is stored in the following csv table:

# %%
hv_bus_sw = pd.read_csv('example_advanced/hv_bus_sw.csv', sep=';', header=0, decimal=',')
hv_bus_sw

# %%
# Bus-bus switches
for _, switch in hv_bus_sw.iterrows():
    from_bus = get_element_index(net, "bus", switch.from_bus)
    to_bus = get_element_index(net, "bus", switch.to_bus)
    create_switch(net, from_bus, to_bus, et=switch.et, closed=switch.closed, type=switch.type, name=switch.bus_name)

# Bus-line switches
hv_buses = net.bus[(net.bus.vn_kv == 380) | (net.bus.vn_kv == 110)].index
hv_ls = net.line[(net.line.from_bus.isin(hv_buses)) & (net.line.to_bus.isin(hv_buses))]
for _, line in hv_ls.iterrows():
        create_switch(net, line.from_bus, line.name, et='l', closed=True, type='LBS', name=f"Switch {net.bus.name.at[line.from_bus]} - {line['name']}")
        create_switch(net, line.to_bus, line.name, et='l', closed=True, type='LBS', name=f"Switch {net.bus.name.at[line.to_bus]} - {line['name']}")

# Trafo-line switches
create_switch(net, get_element_index(net, "bus", 'Bus DB 2'), get_element_index(net, "trafo", 'EHV-HV-Trafo'), et='t', closed=True, type='LBS', name='Switch DB2 - EHV-HV-Trafo')
create_switch(net, get_element_index(net, "bus", 'Bus SB 1'), get_element_index(net, "trafo", 'EHV-HV-Trafo'), et='t', closed=True, type='LBS', name='Switch SB1 - EHV-HV-Trafo')

# show switch table
net.switch

# %% [markdown]
# ### External Grid
#
# <img src="pics/example_network_ext_grids_hv.png" width="40%">

# %% [markdown]
# We equip the high voltage side of the transformer with an external grid connection:

# %%
create_ext_grid(net, get_element_index(net, "bus", 'Double Busbar 1'), vm_pu=1.03, va_degree=0, name='External grid',
                   s_sc_max_mva=10000, rx_max=0.1, rx_min=0.1)

net.ext_grid # show external grid table

# %% [markdown]
# ### Loads
#
# <img src="pics/example_network_loads_hv.png" width="40%">

# %% [markdown]
# The five loads in the HV network are defined in the following csv file:

# %%
hv_loads = pd.read_csv('example_advanced/hv_loads.csv', sep=';', header=0, decimal=',')
hv_loads

# %%
for _, load in hv_loads.iterrows():
    bus_idx = get_element_index(net, "bus", load.bus)
    create_load(net, bus_idx, p_mw=load.p, q_mvar=load.q, name=load.load_name)

# show load table
net.load

# %% [markdown]
# ### Generator
#
# <img src="pics/example_network_gens_hv.png" width="40%">

# %% [markdown]
# The voltage controlled generator is created with an active power of 100 MW (negative for generation) and a voltage set point of 1.03 per unit:

# %%
create_gen(net, get_element_index(net, "bus", 'Bus HV4'), vm_pu=1.03, p_mw=100, name='Gas turbine')

# show generator table
net.gen

# %% [markdown]
# ### Static generators
#
# <img src="pics/example_network_sgens_hv.png" width="40%">

# %% [markdown]
# We create this wind park with an active power of 20 MW (negative for generation) and a reactive power of -4 Mvar. To classify the generation as a wind park, we set type to "WP":

# %%
create_sgen(net, get_element_index(net, "bus", 'Bus SB 5'), p_mw=20, q_mvar=4, sn_mva=45, 
               type='WP', name='Wind Park')

# show static generator table
net.sgen

# %% [markdown]
# ### Shunt
#
# <img src="pics/example_network_shunts_hv.png" width="40%">

# %%
create_shunt(net, bus1, p_mw=0, q_mvar=0.960, name='Shunt')

# show shunt table
net.shunt

# %% [markdown]
# ### External network equivalents
#
#
# <img src="pics/example_network_ext_equi_hv.png" width="40%">

# %% [markdown]
# The two remaining elements are impedances and extended ward equivalents:

# %%
# Impedance
create_impedance(net, get_element_index(net, "bus", 'Bus HV3'), bus1,
                    rft_pu=0.074873, xft_pu=0.198872, sn_mva=100, name='Impedance')

# show impedance table
net.impedance

# %%
# xwards
create_xward(net, get_element_index(net, "bus", 'Bus HV3'), ps_mw=23.942, qs_mvar=-12.24187, pz_mw=2.814571, 
                qz_mvar=0, r_ohm=0, x_ohm=12.18951, vm_pu=1.02616, name='XWard 1')
create_xward(net, bus1, ps_mw=3.776, qs_mvar=-7.769979, pz_mw=9.174917,
                qz_mvar=0, r_ohm=0, x_ohm=50.56217, vm_pu=1.024001, name='XWard 2')

# show xward table
net.xward

# %% [markdown]
# ## Medium voltage level

# %% [markdown]
# ### Buses
#
# <img src="pics/example_network_buses_mv.png" width="50%">

# %%
create_bus(net, name='Bus MV0 20kV', vn_kv=20, type='n')
for i in range(8):
    create_bus(net, name='Bus MV%s' % i, vn_kv=10, type='n')

#show only medium voltage bus table
mv_buses = net.bus[(net.bus.vn_kv == 10) | (net.bus.vn_kv == 20)]
mv_buses

# %% [markdown]
# ### Lines
#
# <img src="pics/example_network_lines_mv.png" width="50%">

# %%
mv_lines = pd.read_csv('example_advanced/mv_lines.csv', sep=';', header=0, decimal=',')
for _, mv_line in mv_lines.iterrows():
    from_bus = get_element_index(net, "bus", mv_line.from_bus)
    to_bus = get_element_index(net, "bus", mv_line.to_bus)
    create_line(net, from_bus, to_bus, length_km=mv_line.length, std_type=mv_line.std_type, name=mv_line.line_name)

# show only medium voltage lines
net.line[net.line.from_bus.isin(mv_buses.index)]

# %% [markdown]
# ### 3 Winding Transformer
#
# <img src="pics/example_network_trafos_mv.png" width="50%">

# %% [markdown]
# The three winding transformer transforms its high voltage level to two different lower voltage levels, in this case from 110 kV to 20 kV and 10 kV.

# %%
hv_bus = get_element_index(net, "bus", "Bus HV2")
mv_bus = get_element_index(net, "bus", "Bus MV0 20kV")
lv_bus = get_element_index(net, "bus", "Bus MV0")
create_transformer3w_from_parameters(net, hv_bus, mv_bus, lv_bus, vn_hv_kv=110, vn_mv_kv=20, vn_lv_kv=10, 
                                        sn_hv_mva=40, sn_mv_mva=15, sn_lv_mva=25, vk_hv_percent=10.1, 
                                        vk_mv_percent=10.1, vk_lv_percent=10.1, vkr_hv_percent=0.266667, 
                                        vkr_mv_percent=0.033333, vkr_lv_percent=0.04, pfe_kw=0, i0_percent=0, 
                                        shift_mv_degree=30, shift_lv_degree=30, tap_side="hv", tap_neutral=0, tap_min=-8, 
                                        tap_max=8, tap_step_percent=1.25, tap_pos=0, name='HV-MV-MV-Trafo', 
                                        tap_changer_type="Ratio")

# show transformer3w table
net.trafo3w

# %% [markdown]
# ### Switches

# %%
# Bus-line switches
mv_buses = net.bus[(net.bus.vn_kv == 10) | (net.bus.vn_kv == 20)].index
mv_ls = net.line[(net.line.from_bus.isin(mv_buses)) & (net.line.to_bus.isin(mv_buses))]
for _, line in mv_ls.iterrows():
        create_switch(net, line.from_bus, line.name, et='l', closed=True, type='LBS', name=f"Switch {net.bus.name.at[line.from_bus]} - {line['name']}")
        create_switch(net, line.to_bus, line.name, et='l', closed=True, type='LBS', name=f"Switch {net.bus.name.at[line.to_bus]} - {line['name']}")

# open switch
open_switch_id = net.switch[(net.switch.name == 'Switch Bus MV5 - MV Line5')].index
net.switch.closed.loc[open_switch_id] = False

#show only medium voltage switch table
net.switch[net.switch.bus.isin(mv_buses)]

# %% [markdown]
# ### Loads
#
# <img src="pics/example_network_loads_mv.png"  width="50%">

# %%
mv_loads = pd.read_csv('example_advanced/mv_loads.csv', sep=';', header=0, decimal=',')
for _, load in mv_loads.iterrows():
    bus_idx = get_element_index(net, "bus", load.bus)
    create_load(net, bus_idx, p_mw=load.p, q_mvar=load.q, name=load.load_name)

# show only medium voltage loads
net.load[net.load.bus.isin(mv_buses)]

# %% [markdown]
# ### Static generators
#
# <img src="pics/example_network_sgens_mv.png"  width="50%">

# %%
mv_sgens = pd.read_csv('example_advanced/mv_sgens.csv', sep=';', header=0, decimal=',')
for _, sgen in mv_sgens.iterrows():
    bus_idx = get_element_index(net, "bus", sgen.bus)
    create_sgen(net, bus_idx, p_mw=sgen.p, q_mvar=sgen.q, sn_mva=sgen.sn, type=sgen.type, name=sgen.sgen_name)

# show only medium voltage static generators
net.sgen[net.sgen.bus.isin(mv_buses)]

# %% [markdown]
# ## Low voltage level

# %% [markdown]
# ### Busses
#
# <img src="pics/example_network_buses_lv.png" width="50%">

# %%
create_bus(net, name='Bus LV0', vn_kv=0.4, type='n')
for i in range(1, 6):
    create_bus(net, name='Bus LV1.%s' % i, vn_kv=0.4, type='m')
for i in range(1, 5):
    create_bus(net, name='Bus LV2.%s' % i, vn_kv=0.4, type='m')
create_bus(net, name='Bus LV2.2.1', vn_kv=0.4, type='m')
create_bus(net, name='Bus LV2.2.2', vn_kv=0.4, type='m')

# show only low voltage buses
lv_buses = net.bus[net.bus.vn_kv == 0.4]
lv_buses

# %% [markdown]
# ### Lines
#
# <img src="pics/example_network_lines_lv.png" width="50%">

# %%
# create lines
lv_lines = pd.read_csv('example_advanced/lv_lines.csv', sep=';', header=0, decimal=',')
for _, lv_line in lv_lines.iterrows():
    from_bus = get_element_index(net, "bus", lv_line.from_bus)
    to_bus = get_element_index(net, "bus", lv_line.to_bus)
    create_line(net, from_bus, to_bus, length_km=lv_line.length, std_type=lv_line.std_type, name=lv_line.line_name)

# show only low voltage lines
net.line[net.line.from_bus.isin(lv_buses.index)]

# %% [markdown]
# ### Transformer
#
# <img src="pics/example_network_trafos_lv.png" width="50%">

# %%
hv_bus = get_element_index(net, "bus", "Bus MV4")
lv_bus = get_element_index(net, "bus","Bus LV0")
create_transformer_from_parameters(net, hv_bus, lv_bus, sn_mva=.4, vn_hv_kv=10, vn_lv_kv=0.4, vkr_percent=1.325, vk_percent=4, pfe_kw=0.95, i0_percent=0.2375, tap_side="hv", tap_neutral=0, tap_min=-2, tap_max=2, tap_step_percent=2.5, tap_changer_type="Ratio", tp_pos=0, shift_degree=150, name='MV-LV-Trafo')

#show only low voltage transformer
net.trafo[net.trafo.lv_bus.isin(lv_buses.index)]

# %% [markdown]
# ### Switches

# %%
lv_buses
# Bus-line switches
lv_ls = net.line[(net.line.from_bus.isin(lv_buses.index)) & (net.line.to_bus.isin(lv_buses.index))]
for _, line in lv_ls.iterrows():
        create_switch(net, line.from_bus, line.name, et='l', closed=True, type='LBS', name=f"Switch {net.bus.name.at[line.from_bus]} - {line['name']}")
        create_switch(net, line.to_bus, line.name, et='l', closed=True, type='LBS', name=f"Switch {net.bus.name.at[line.to_bus]} - {line['name']}")

# Trafo-line switches
create_switch(net, get_element_index(net, "bus", 'Bus MV4'), get_element_index(net, "trafo", 'MV-LV-Trafo'), et='t', closed=True, type='LBS', name='Switch MV4 - MV-LV-Trafo')
create_switch(net, get_element_index(net, "bus", 'Bus LV0'), get_element_index(net, "trafo", 'MV-LV-Trafo'), et='t', closed=True, type='LBS', name='Switch LV0 - MV-LV-Trafo')

# show only low vvoltage switches
net.switch[net.switch.bus.isin(lv_buses.index)]

# %% [markdown]
# ### Loads
#
# <img src="pics/example_network_loads_lv.png" width="50%">

# %%
lv_loads = pd.read_csv('example_advanced/lv_loads.csv', sep=';', header=0, decimal=',')
for _, load in lv_loads.iterrows():
    bus_idx = get_element_index(net, "bus", load.bus)
    create_load(net, bus_idx, p_mw=load.p, q_mvar=load.q, name=load.load_name)
    
# show only low voltage loads
net.load[net.load.bus.isin(lv_buses.index)]

# %% [markdown]
# ### Static generators
#
# <img src="pics/example_network_sgens_lv.png"  width="50%">

# %%
lv_sgens = pd.read_csv('example_advanced/lv_sgens.csv', sep=';', header=0, decimal=',')
for _, sgen in lv_sgens.iterrows():
    bus_idx = get_element_index(net, "bus", sgen.bus)
    create_sgen(net, bus_idx, p_mw=sgen.p, q_mvar=sgen.q, sn_mva=sgen.sn, type=sgen.type, name=sgen.sgen_name)

# show only low voltage static generators
net.sgen[net.sgen.bus.isin(lv_buses.index)]

# %% [markdown]
# ## Run a Power Flow

# %%
runpp(net, calculate_voltage_angles=True, init="dc")
net
